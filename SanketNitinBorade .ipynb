# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
customer = pd.read_csv("C:\\Users\\Hp\\Downloads\\project\\customers.csv")
customer
# Out:
#      customer_id gender  age       city signup_date     income loyalty_segment
# 0      CUST00001   Male   56     Mumbai  2021-01-08   794055.0         Regular
# 1      CUST00002   Male   46     Mumbai  2021-07-27  1352908.0         Regular
# 2      CUST00003   Male   32     Mumbai  2021-08-14   730624.0         Regular
# 3      CUST00004   Male   60     Mumbai  2022-10-05   574344.0         Regular
# 4      CUST00005   Male   25     Mumbai  2022-12-13        NaN         Regular
# ...          ...    ...  ...        ...         ...        ...             ...
# 5434   CUST05435  Other   59     Nagpur  2022-10-07        NaN        Platinum
# 5435   CUST05436  Other   26  Bangalore  2023-01-11  1346237.0        Platinum
# 5436   CUST05437  Other   43  Bangalore  2021-10-13   915042.0        Platinum
# 5437   CUST05438  Other   37     Nagpur  2022-11-27   899560.0        Platinum
# 5438   CUST05439  Other   57     Nagpur  2021-05-24   222970.0        Platinum
#
# [5439 rows x 7 columns]

# %%
# using this info we see the quick structure summary of the dataset 
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5439 entries, 0 to 5438
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      5439 non-null   object
#  1   gender           5439 non-null   object
#  2   age              5439 non-null   int64
#  3   city             5439 non-null   object
#  4   signup_date      5439 non-null   object
#  5   income           4609 non-null   float64
#  6   loyalty_segment  5439 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 297.6+ KB

# %%
# using the describe we see all the  numerical columns of the dataset 
customer.describe()
# Out:
#                age        income
# count  5439.000000  4.609000e+03
# mean     41.203162  8.528372e+05
# std      13.488478  3.753823e+05
# min      18.000000  2.000640e+05
# 25%      30.000000  5.275260e+05
# 50%      41.000000  8.545390e+05
# 75%      53.000000  1.174501e+06
# max      64.000000  1.499825e+06

# %%
# here we see the null values 
customer["income"].isnull().sum()
# Out:
# np.int64(830)

# %%
# In the column there are null values so we replaces missing values 
customer["income"].fillna(df["income"].median(),inplace=True)
# Out:
# C:\Windows\Temp\ipykernel_24044\4122477122.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customer["income"].fillna(df["income"].median(),inplace=True)

# %%
# now we see the null valus  replace or not 
customer.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5439 entries, 0 to 5438
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      5439 non-null   object
#  1   gender           5439 non-null   object
#  2   age              5439 non-null   int64
#  3   city             5439 non-null   object
#  4   signup_date      5439 non-null   object
#  5   income           5439 non-null   float64
#  6   loyalty_segment  5439 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 297.6+ KB

# %%
#here we check a null values from the dataset 
customer.isnull().sum()
# Out:
# customer_id        0
# gender             0
# age                0
# city               0
# signup_date        0
# income             0
# loyalty_segment    0
# dtype: int64

# %%
# here we have to calculates the number of unique valus from this column 
customer["customer_id"].nunique()
# Out:
# 5439

# %%
# using this we see a duplicate values from a dataset
customer[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, gender, age, city, signup_date, income, loyalty_segment]
# Index: []

# %%
# in the dataset there is one mistake in datatype of signup so we can correct it 
customer["signup_date"]=pd.to_datetime(df["signup_date"])

# %%
# now we check the datatype 
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5439 entries, 0 to 5438
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      5439 non-null   object
#  1   gender           5439 non-null   object
#  2   age              5439 non-null   int64
#  3   city             5439 non-null   object
#  4   signup_date      5439 non-null   datetime64[ns]
#  5   income           5439 non-null   float64
#  6   loyalty_segment  5439 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 297.6+ KB

# %%
# here we print all the uniques valus from this columns and check the formating 
print(customer["gender"].unique())
print("-----------------------------------------")

print(customer["customer_id"].unique())
print("-----------------------------------------")

print(customer["city"].unique())
print("------------------------------------------")

print(customer["loyalty_segment"].unique())
# Out:
# ['Male' 'Female' 'Other']
# -----------------------------------------
# ['CUST00001' 'CUST00002' 'CUST00003' ... 'CUST05437' 'CUST05438'
#  'CUST05439']
# -----------------------------------------
# ['Mumbai' 'Pune' 'Delhi' 'Hyderabad' 'Chennai' 'Nagpur' 'Bangalore']
# ------------------------------------------
# ['Regular' 'Silver' 'Gold' 'Platinum']

# %%
customer['income'].plot(kind='box')
# Out:
# <Axes: >

# %%
# import the location dataset
location=pd.read_csv("C:\\Users\\Hp\\Downloads\\project\\locations.csv")
location
# Out:
#          city        state   region  population
# 0      Mumbai  Maharashtra     West    20000000
# 1        Pune  Maharashtra     West     7000000
# 2       Delhi        Delhi    North    19000000
# 3      Nagpur  Maharashtra     West     2500000
# 4   Bangalore    Karnataka    South    12000000
# 5   Hyderabad    Telangana    South    10000000
# 6     Chennai   Tamil Nadu    South     9000000
# 7     Kolkata  West Bengal     East    14000000
# 8      Jaipur    Rajasthan    North     3500000
# 9       Surat      Gujarat     West     6000000
# 10    Lucknow           UP    North     4500000
# 11     Indore           MP  Central     3000000
# 12     Bhopal           MP  Central     2500000
# 13  Ahmedabad      Gujarat     West     8000000
# 14      Patna        Bihar     East     3500000

# %%
# here we see all the info about dataset
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        15 non-null     object
#  1   state       15 non-null     object
#  2   region      15 non-null     object
#  3   population  15 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 612.0+ bytes

# %%
# Here we see a numercical column and all about the numerical columns 
location.describe()
# Out:
#          population
# count  1.500000e+01
# mean   8.300000e+06
# std    5.756363e+06
# min    2.500000e+06
# 25%    3.500000e+06
# 50%    7.000000e+06
# 75%    1.100000e+07
# max    2.000000e+07

# %%
# here we see all the null values afrom the dataset 
location.isnull().sum()
# Out:
# city          0
# state         0
# region        0
# population    0
# dtype: int64

# %%
# using this we see a duplicate values from a dataset
location[location.duplicated()]
# Out:
# Empty DataFrame
# Columns: [city, state, region, population]
# Index: []

# %%
# here we print all the uniques valus from this columns and check the formating 

print(location["city"].unique())
print("--------------------------------------------------------")

print(location["state"].unique())
print("--------------------------------------------------------")

print(location["region"].unique())
# Out:
# ['Mumbai' 'Pune' 'Delhi' 'Nagpur' 'Bangalore' 'Hyderabad' 'Chennai'
#  'Kolkata' 'Jaipur' 'Surat' 'Lucknow' 'Indore' 'Bhopal' 'Ahmedabad'
#  'Patna']
# --------------------------------------------------------
# ['Maharashtra' 'Delhi' 'Karnataka' 'Telangana' 'Tamil Nadu' 'West Bengal'
#  'Rajasthan' 'Gujarat' 'UP' 'MP' 'Bihar']
# --------------------------------------------------------
# ['West' 'North' 'South' 'East' 'Central']

# %%
# here we check the outlier in the population column 
print(location['population'].describe())
print(location['population'].plot(kind='box'))
# Out:
# count    1.500000e+01
# mean     8.300000e+06
# std      5.756363e+06
# min      2.500000e+06
# 25%      3.500000e+06
# 50%      7.000000e+06
# 75%      1.100000e+07
# max      2.000000e+07
# Name: population, dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %%
# importing the product dataset 
product=pd.read_csv("C:\\Users\\Hp\\Downloads\\project\\products.csv")
product
# Out:
#      product_id     category   brand  cost_price launch_date
# 0      PROD0001  Electronics  BrandE       11728  2024-02-06
# 1      PROD0002  Electronics  BrandC       38219  2022-01-08
# 2      PROD0003  Electronics  BrandC        4653  2023-10-09
# 3      PROD0004  Electronics  BrandB        6618  2021-04-21
# 4      PROD0005  Electronics  BrandE       38591  2020-10-04
# ...         ...          ...     ...         ...         ...
# 1195   PROD1196         Home  BrandE       18857  2022-04-24
# 1196   PROD1197         Home  BrandB       25512  2022-12-14
# 1197   PROD1198         Home  BrandA       14412  2021-03-05
# 1198   PROD1199         Home  BrandD       22219  2021-10-23
# 1199   PROD1200         Home  BrandC       11904  2021-04-14
#
# [1200 rows x 5 columns]

# %%
# here we sww all information about the dataset
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_id   1200 non-null   object
#  1   category     1200 non-null   object
#  2   brand        1200 non-null   object
#  3   cost_price   1200 non-null   int64
#  4   launch_date  1200 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 47.0+ KB

# %%
# here we see all the numerical columns and all info about the numerical column 
product.describe()
# Out:
#         cost_price
# count   1200.00000
# mean   25081.41500
# std    14274.25802
# min      159.00000
# 25%    13484.25000
# 50%    24584.00000
# 75%    37327.25000
# max    49971.00000

# %%
# here we see all the null  values from the dataset
product.isnull().sum()
# Out:
# product_id     0
# category       0
# brand          0
# cost_price     0
# launch_date    0
# dtype: int64

# %%
# using this we see a duplicate values from a dataset
product[product.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, category, brand, cost_price, launch_date]
# Index: []

# %%
#Here we can change the datatype 
product["launch_date"]=pd.to_datetime(product["launch_date"])

# %%
# now we have to check a data type chnge or not 
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_id   1200 non-null   object
#  1   category     1200 non-null   object
#  2   brand        1200 non-null   object
#  3   cost_price   1200 non-null   int64
#  4   launch_date  1200 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 47.0+ KB

# %%
# here we print all the uniques valus from this columns and check the formating 

print(product["product_id"].unique())
print("-------------------------------------------------------------")

print(product["category"].unique())
print("-------------------------------------------------------------")

print(product["brand"].unique())
# Out:
# ['PROD0001' 'PROD0002' 'PROD0003' ... 'PROD1198' 'PROD1199' 'PROD1200']
# -------------------------------------------------------------
# ['Electronics' 'Fashion' 'Grocery' 'Home']
# -------------------------------------------------------------
# ['BrandE' 'BrandC' 'BrandB' 'BrandD' 'BrandA']

# %%
#checking for the outlier in numerical columns 
print(product['cost_price'].plot(kind='box'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
transation=pd.read_csv("C:\\Users\\Hp\\Downloads\\project\\transactions.csv")
transation
# Out:
#       transaction_id customer_id product_id transaction_date  quantity  \
# 0          TXN000001   CUST04835   PROD0883       2022-03-15         2
# 1          TXN000002   CUST02792   PROD0907       2022-03-19         1
# 2          TXN000003   CUST05424   PROD0738       2023-09-26         2
# 3          TXN000004   CUST04213   PROD0127       2023-04-04         1
# 4          TXN000005   CUST03984   PROD1140       2023-06-24         5
# ...              ...         ...        ...              ...       ...
# 25455      TXN025456   CUST00010   PROD0820       2022-11-06         1
# 25456      TXN025457   CUST03099   PROD1101       2023-06-04         5
# 25457      TXN025458   CUST02817   PROD0480       2022-01-25         2
# 25458      TXN025459   CUST00327   PROD0284       2023-08-22         3
# 25459      TXN025460   CUST03567   PROD1182       2022-03-23         5
#
#       unit_price  discount_percent payment_mode  delivery_days returned
# ...

# %%
# using this info we see the quick structure summary of the dataset 

transation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25460 entries, 0 to 25459
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    25460 non-null  object
#  1   customer_id       25460 non-null  object
#  2   product_id        25460 non-null  object
#  3   transaction_date  25460 non-null  object
#  4   quantity          25460 non-null  int64
#  5   unit_price        25460 non-null  object
#  6   discount_percent  25460 non-null  int64
#  7   payment_mode      25460 non-null  object
#  8   delivery_days     25460 non-null  int64
#  9   returned          25460 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 1.9+ MB

# %%
# using the describe we see tall the  numerical columns of the dataset and all about the numerical columns

transation.describe()
# Out:
#            quantity  discount_percent  delivery_days
# count  25460.000000      25460.000000   25460.000000
# mean      48.237706         19.398979       4.322742
# std      208.799664         11.501514       3.748312
# min        1.000000          0.000000      -3.000000
# 25%        1.000000         10.000000       1.000000
# 50%        2.000000         19.000000       4.000000
# 75%        4.000000         29.000000       7.000000
# max     1000.000000         39.000000      10.000000

# %%
# here we see the null values 
transation.isnull().sum()
# Out:
# transaction_id      0
# customer_id         0
# product_id          0
# transaction_date    0
# quantity            0
# unit_price          0
# discount_percent    0
# payment_mode        0
# delivery_days       0
# returned            0
# dtype: int64

# %%
#cleaning the column 
# In thid transaction  table in unit_price column values where in the object data type so it removed the rupess symbol and unwanted space then converted into int datatype
transation['unit_price'] = (transation['unit_price'].str.replace('₹', '', regex=False).str.replace(',', '', regex=False).astype(int))

# %%
transation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25460 entries, 0 to 25459
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    25460 non-null  object
#  1   customer_id       25460 non-null  object
#  2   product_id        25460 non-null  object
#  3   transaction_date  25460 non-null  datetime64[ns]
#  4   quantity          25460 non-null  int64
#  5   unit_price        25460 non-null  int64
#  6   discount_percent  25460 non-null  int64
#  7   payment_mode      25460 non-null  object
#  8   delivery_days     25460 non-null  int64
#  9   returned          25460 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 1.9+ MB

# %%
# here we have to calculates the number of unique valus from this column 
transation["transaction_id"].nunique()
# Out:
# 25460

# %%
# using this we see a duplicate values from a dataset

transation[transation.duplicated()]
# Out:
# Empty DataFrame
# Columns: [transaction_id, customer_id, product_id, transaction_date, quantity, unit_price, discount_percent, payment_mode, delivery_days, returned]
# Index: []

# %%
# here we look the datatype is correct or not if not correct so correct it using this 
transation["transaction_date"]=pd.to_datetime(transation["transaction_date"])

# %%
# noe we check the correct datatype
transation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25460 entries, 0 to 25459
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    25460 non-null  object
#  1   customer_id       25460 non-null  object
#  2   product_id        25460 non-null  object
#  3   transaction_date  25460 non-null  datetime64[ns]
#  4   quantity          25460 non-null  int64
#  5   unit_price        25460 non-null  object
#  6   discount_percent  25460 non-null  int64
#  7   payment_mode      25460 non-null  object
#  8   delivery_days     25460 non-null  int64
#  9   returned          25460 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 1.9+ MB

# %%
# here we print all the uniques valus from this columns and check the formating 

print(transation["transaction_id"].unique())
print("---------------------------------------------------------------------:")
      
print(transation["customer_id"].unique())
print("---------------------------------------------------------------------:")

print(transation["product_id"].unique())
print("---------------------------------------------------------------------:")

print(transation["unit_price"].unique())
print("---------------------------------------------------------------------:")

print(transation["returned"].unique())
# Out:
# ['TXN000001' 'TXN000002' 'TXN000003' ... 'TXN025458' 'TXN025459'
#  'TXN025460']
# ---------------------------------------------------------------------:
# ['CUST04835' 'CUST02792' 'CUST05424' ... 'CUST05286' 'CUST00995'
#  'CUST01422']
# ---------------------------------------------------------------------:
# ['PROD0883' 'PROD0907' 'PROD0738' ... 'PROD1073' 'PROD0222' 'PROD0613']
# ---------------------------------------------------------------------:
# ['₹35,143' '₹27,217' '₹13,363' ... '₹25,844' '₹21,893' '₹43,469']
# ---------------------------------------------------------------------:
# ['No' 'Yes']

# %%
#checking outlier'
print(transation['unit_price'].plot(kind='box'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(transation['discount_percent'].plot(kind='box'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(transation['delivery_days'].plot(kind='box'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
# from this four tables transcation table is the fact table and product,customer and location are the daimension table 
#transction table merge with customer table 
df = pd.merge(transation,customer , on='customer_id',how='left',validate='many_to_one')
df= pd.merge(df,location,on='city',how='left',validate='many_to_one')
df = pd.merge(df,product,on='product_id',how='left',validate='many_to_one')
print(f'length before merge : {len(transation)} length adfter merge  {len(df)}')
# Out:
# length before merge : 25460 length adfter merge  25460

# %%
df.to_csv('SanketNitinBorade_cleaned_assissment',index=False)

# %%
df
# Out:
#       transaction_id customer_id product_id transaction_date  quantity  \
# 0          TXN000001   CUST04835   PROD0883       2022-03-15         2
# 1          TXN000002   CUST02792   PROD0907       2022-03-19         1
# 2          TXN000003   CUST05424   PROD0738       2023-09-26         2
# 3          TXN000004   CUST04213   PROD0127       2023-04-04         1
# 4          TXN000005   CUST03984   PROD1140       2023-06-24         5
# ...              ...         ...        ...              ...       ...
# 25455      TXN025456   CUST00010   PROD0820       2022-11-06         1
# 25456      TXN025457   CUST03099   PROD1101       2023-06-04         5
# 25457      TXN025458   CUST02817   PROD0480       2022-01-25         2
# 25458      TXN025459   CUST00327   PROD0284       2023-08-22         3
# 25459      TXN025460   CUST03567   PROD1182       2022-03-23         5
#
#        unit_price  discount_percent payment_mode  delivery_days returned  ...  \
# ...

# %%
#calculating the reveuie 
revenue = transation['unit_price'] * transation['quantity']
actual_revenue = revenue.sum()
actual_revenue
# Out:
# np.int64(30127071628)

# %%
# calculating profit  
#using df1 is merge of (transaction/product) table 
profit = (df['unit_price'] - df['cost_price']) * df['quantity']
actual_profit = profit.sum()
actual_profit
# Out:
# np.int64(74388902)

# %%
# Here we can calculating total return orders 
return_orders = df['returned'] == 'Yes'
actual_return_orders = return_orders.sum()
print(f'total return order : {actual_return_orders}')

#calculating total orders 
total_order =  df['transaction_id'].count()
print(f'total orders : {total_order}')
# Out:
# total return order : 3819
# total orders : 25460

# %%
# here we can calculating return rate 
total_order =  df['transaction_id'].count()
returns = (actual_return_orders /  total_order) * 100
returns
# Out:
# np.float64(15.0)

# %%
# here we calculating CLV 
cust = df['customer_id'].nunique()
clv = actual_revennue / cust
clv
# Out:
# np.float64(5581154.432752872)

# %%
# here we see the returns information by the gender
gender_returens = df.groupby('gender')['returned'].value_counts()
gender_returens
# Out:
# gender  returned
# Female  No           7118
#         Yes          1256
# Male    No          14068
#         Yes          2479
# Other   No            455
#         Yes            84
# Name: count, dtype: int64

# %%
# here we calculate  a pie char of the customer distribution by city 
city_customers = df.groupby('city')['customer_id'].nunique()

plt.pie(city_customers, labels=city_customers.index, autopct='%1.1f%%')
plt.title("Customer Distribution by City")
plt.show()

# %%
# here we can calculate the total orders done by the gender by the city 
dis = df.groupby('gender')['city'].value_counts()
dis
# Out:
# gender  city
# Female  Pune          3833
#         Delhi         2469
#         Nagpur         558
#         Hyderabad      537
#         Bangalore      503
#         Chennai        474
# Male    Mumbai       15242
#         Pune          1305
# Other   Bangalore      157
#         Nagpur         143
#         Chennai        123
#         Hyderabad      116
# Name: count, dtype: int64

# %%
# here we can checking the total income from the customer 
income_customer = df.groupby('customer_id')['income'].value_counts()
income_customer
# Out:
# customer_id  income
# CUST00001    794055.0     7
# CUST00002    1352908.0    3
# CUST00003    730624.0     2
# CUST00004    574344.0     8
# CUST00005    854539.0     1
#                          ..
# CUST05435    854539.0     5
# CUST05436    1346237.0    6
# CUST05437    915042.0     3
# CUST05438    899560.0     5
# CUST05439    222970.0     4
# Name: count, Length: 5398, dtype: int64

# %%
# here we can checking  category wise  brands are selling
df.groupby('category')['brand'].value_counts()
# Out:
# category     brand
# Electronics  BrandB    2887
#              BrandE    2684
#              BrandA    2648
#              BrandC    2457
#              BrandD    2181
# Fashion      BrandC    1538
#              BrandA    1335
#              BrandD    1271
#              BrandB    1238
#              BrandE    1009
# Grocery      BrandC     824
#              BrandE     819
#              BrandB     714
#              BrandD     691
#              BrandA     644
# Home         BrandA     611
#              BrandE     568
#              BrandC     454
#              BrandB     453
#              BrandD     434
# Name: count, dtype: int64

# %%
# here we can checking the used upi mode 
df['payment_mode'].value_counts()
# Out:
# payment_mode
# UPI       12730
# Card       7638
# COD        3819
# Wallet     1273
# Name: count, dtype: int64

# %%
# here we can count the loyalty_segment
df['loyalty_segment'].value_counts()
# Out:
# loyalty_segment
# Regular     17843
# Silver       5013
# Gold         2065
# Platinum      539
# Name: count, dtype: int64

# %%
# here we can count top five launched date 
df['launch_date'].value_counts().head()
# Out:
# launch_date
# 2022-10-15    166
# 2022-05-13    105
# 2020-05-29    101
# 2023-01-28     97
# 2020-09-08     96
# Name: count, dtype: int64

# %%
# here we can calculate the region 
df['region'].value_counts()
# Out:
# region
# West     21081
# North     2469
# South     1910
# Name: count, dtype: int64

# %%
# here we can  checkinmg region wise reveue 
df['total_reveune'] = df['unit_price']  * df['quantity']
df.groupby('region')['total_reveune'].sum()
# Out:
# region
# North     3078061404
# South     2589019162
# West     24459991062
# Name: total_reveune, dtype: int64

# %%
# here we can calculate state orders
df['state'].value_counts()
# Out:
# state
# Maharashtra    21081
# Delhi           2469
# Karnataka        660
# Telangana        653
# Tamil Nadu       597
# Name: count, dtype: int64

# %%
# here we can check the loyalty_segment by state 
df.groupby('state')['loyalty_segment'].value_counts()
# Out:
# state        loyalty_segment
# Delhi        Silver              2469
# Karnataka    Gold                 503
#              Platinum             157
# Maharashtra  Regular            17843
#              Silver              2537
#              Gold                 558
#              Platinum             143
# Tamil Nadu   Gold                 474
#              Platinum             123
# Telangana    Gold                 530
#              Platinum             116
#              Silver                 7
# Name: count, dtype: int64

# %%
# here we count the  region wise population
df.groupby('region')['region'].value_counts()
# Out:
# region
# North     2469
# South     1910
# West     21081
# Name: count, dtype: int64
